# %% [markdown]
# # Probando pruebas

# %%
import requests

response = requests.get("https://infobus.bucr.digital/api/" + "stops")
print(response.status_code)
print(response.text)
stops = response.json()

for stop in stops:
    print(stop["stop_id"] + " " + stop["stop_name"])
# Out:
# 200
# ...
